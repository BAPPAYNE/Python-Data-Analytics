# %%
import pandas as pd
import numpy as np
file = pd.read_csv('placement.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 file = pd.read_csv('placement.csv')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
file = file.iloc[:,1:]
file.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
# %matplotlib
import matplotlib.pyplot as plt
plt.scatter(file['cgpa'],file['iq'])
